# %%
import sys
import os

sys.path.append(os.path.abspath("../tools"))
from envvars import load_env_vars_from_directory
import numpy as np
import pandas as pd
import faiss
import glob
import re
import pysrt
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup, Comment

# %%
# Variables de entorno
# Cargar variables de entorno desde archivos .env
load_env_vars_from_directory("../.env")

# Comprobar si las variables de entorno necesarias están definidas
cal_file =os.getenv('PODCAST_CAL_FILE')
if not cal_file:
    raise ValueError("PODCAST_CAL_FILE environment variable is not set.")
if not os.path.exists(cal_file):
    raise FileNotFoundError(f"Calendar '{cal_file}' does not exist.")
workdir = os.path.join(os.getenv('PODCAST_WORKDIR'), 'Tmp')
if not workdir:
    raise ValueError("PODCAST_WORKDIR environment variable is not set.")
if not os.path.exists(workdir):
    raise FileNotFoundError(f"Work directory '{workdir}' does not exist.")
prefix = os.getenv('PODCAST_PREFIX')
if not prefix:
    raise ValueError("PODCAST_PREFIX environment variable is not set.")

# %%
# Leer el calendario de podcasts
caldf = pd.read_csv(cal_file, parse_dates=["date"], index_col="episode" )
caldf
# Out:
#               date
# episode
# 250725  2025-07-25
# 250718  2025-07-18
# 250711  2025-07-11
# 250704  2025-07-04
# 250627  2025-06-27
# ...            ...
# 200201  2020-02-01
# 200125  2020-01-25
# 200118  2020-01-18
# 200111  2020-01-11
# 200104  2020-01-04
#
# [254 rows x 1 columns]

# %%
workdir
# Out:
# '/home/jmrobles/Podcasts/Cowboys de Medianoche/Tmp'

# %%
mp3files = glob.glob(os.path.join(workdir, f"{prefix}*mp3"))
for i in range(len(mp3files)):
    mp3files[i] = os.path.basename(mp3files[i])[:-4]
mp3files[:10]
# Out:
# ['cm220423',
#  'cm241129',
#  'cm241108',
#  'cm250117',
#  'cm220219',
#  'cm250124',
#  'cm230602',
#  'cm240315',
#  'cm230210',
#  'cm250404']

# %%
epnumber_regex = re.compile(rf"{prefix}([\d]+).*")
def get_epnumber(epname):
    global epnumber_regex
    return int(re.search(epnumber_regex, epname).group(1))
epnumbers = [get_epnumber(ep) for ep in mp3files]
print (f"Found {len(epnumbers)} episodes in {workdir} with prefix {prefix}")
print (f"Last 10 epnumbers: {epnumbers[-10:]}")
# Out:
# Found 161 episodes in /home/jmrobles/Podcasts/Cowboys de Medianoche/Tmp with prefix cm
# Last 10 epnumbers: [220514, 250214, 240301, 230929, 230728, 231103, 240419, 230623, 240531, 230519]

# %%
epdf = pd.DataFrame(mp3files, columns=["epname"])
epdf["epnumber"] = epdf["epname"].apply(get_epnumber)

epdf["epdate"] = epdf["epnumber"].apply(
    lambda x: caldf.loc[x]["date"] if x in caldf.index else None
)
epdf.set_index("epname", inplace=True)
epdf
# Out:
#           epnumber     epdate
# epname
# cm220423    220423 2022-04-23
# cm241129    241129 2024-11-29
# cm241108    241108 2024-11-08
# cm250117    250117 2025-01-17
# cm220219    220219 2022-02-19
# ...            ...        ...
# cm231103    231103 2023-11-03
# cm240419    240419 2024-04-19
# cm230623    230623 2023-06-23
# cm240531    240531 2024-05-31
# cm230519    230519 2023-05-19
#
# [161 rows x 2 columns]

# %%
textpat = re.compile(r'^\[(?P<speaker>.*)\]: *(?P<spoken>.*)')

# %%
epints = {}
for epname in epdf.index:
    epsrt = os.path.join(workdir, f"{epname}_whisper_es.srt")
    if not os.path.exists(epsrt):
        print(f"Warning: SRT file for {epname} does not exist, skipping.")
        continue
    epsubs = pysrt.open(epsrt, encoding='utf-8')
    epints[epname] = {}
    for eps in epsubs:
        m = re.match(textpat, eps.text)
        if m is None:
            print (f"Fallo en parsear {eps.text}")
            continue
        speaker = m.group('speaker')
        if speaker.startswith('Unknown'):
            # Si el hablante es desconocido, lo ignoramos
            continue
        # spoken = m.group('spoken')
        start = eps.start.ordinal/1_000
        end = eps.end.ordinal/1_000
        epints[epname][speaker] = epints[epname].get(speaker, 0) + end - start
print(f"Found {len(epints.keys())} episodes with speaker information.")
for k in list(epints.keys())[:5]:
    print(f"{k}: {epints[k]}")
# Out:
# Found 161 episodes with speaker information.
# cm220423: {'Luis Herrero': 838.0099999999993, 'Eduardo Torres-Dulce': 1840.4700000000003, 'José Luis Garci': 1393.199999999999, 'Luis Alberto de Cuenca': 141.15999999999894}
# cm241129: {'Luis Alberto de Cuenca': 961.1800000000012, 'Luis Herrero': 1411.3899999999967, 'José Luis Garci': 1335.1499999999996, 'Eduardo Torres-Dulce': 495.39999999999964, 'Inocencio Arias': 26.980000000000018}
# cm241108: {'Luis Alberto de Cuenca': 236.5699999999997, 'Luis Herrero': 1114.9999999999973, 'Eduardo Torres-Dulce': 1612.7800000000016, 'José Luis Garci': 953.7999999999984}
# cm250117: {'Luis Herrero': 778.1900000000023, 'Luis Alberto de Cuenca': 444.8700000000008, 'Eduardo Torres-Dulce': 1204.859999999997, 'José Luis Garci': 1441.239999999997, 'Inocencio Arias': 370.8600000000006}
# cm220219: {'Luis Herrero': 1163.130000000001, 'Eduardo Torres-Dulce': 1407.960000000001, 'José Luis Garci': 1298.3799999999992, 'Luis Alberto de Cuenca': 156.2500000000009}

# %%
for epname, speakers in epints.items():
    print(f"Processing episode {epname} with speakers {speakers.keys()}")
    html_whisper_files = glob.glob(os.path.join(workdir, f'{epname}*_whisper*.html'))
    for htmlf in html_whisper_files:
        with open(htmlf, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f, 'html.parser')
        comments = soup.find_all(
            string=lambda text: isinstance(text, Comment)
                                and f" ha hablado " in text
        )
        if not comments:
            print(f"No comments found in {htmlf}")
            continue
        if len(comments) < len(speakers):
            print(f"Warning: Not enough comments in {htmlf} for speakers {speakers.keys()}"
                  f" (found: {len(comments)}, expected: {len(speakers)})")
            continue
        speaker_summary = soup.find('span', id='speaker-summary')
        if speaker_summary:
            ul = speaker_summary.find('ul')
            if ul:
                # Borrar los elementos de la lista
                ul.clear()
            else:
                print(f"No 'ul' found in 'speaker-summary' span in {htmlf}")
        else:
            print(f"No 'speaker-summary' span found in {htmlf}")
        cix = 0
        for speaker in speakers:
            # Paso de número de segundos a formato de texto
            seconds = int(speakers[speaker])
            datestr = f"{seconds // 3600:02d}:{(seconds % 3600) // 60:02d}:{seconds % 60:02d}"
            # Reemplazar el comentario con el tiempo de habla
            new_text = f"{speaker} ha hablado {datestr} en el segmento"
            comments[cix].replace_with(Comment(new_text))
            if ul:
                li = soup.new_tag('li')
                li.string = f"{speaker}: {datestr}"
                ul.append(li)
            cix += 1
        for i in range(cix, len(comments)):
            # Borrar los comentarios restantes teniendo en cuenta que no existe clear()
            comments[i].replace_with('')
            
        with open(htmlf, 'w', encoding='utf-8') as f:
            f.write(str(soup))
        #Localizar el span "speaker_summary" y dentro de el una lista ul. Se borrará y rellenará con los hablantes
        # tomados de los comentarios
# Out:
# Processing episode cm220423 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm241129 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias'])
# Processing episode cm241108 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci'])
# Processing episode cm250117 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm220219 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm250124 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias'])
# Processing episode cm230602 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm240315 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm230210 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Daniel Martín'])
# Processing episode cm250404 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm231117 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm240628 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm230106 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm240719 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Noemi Guillermo'])
# Processing episode cm250228 with speakers dict_keys(['Luis Enríquez', 'Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm250704 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias'])
# Processing episode cm250711 with speakers dict_keys(['Luis Enríquez', 'Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm241004 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm250221 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm220430 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Eugenio Jofra Bafalluy', 'Luis Alberto de Cuenca', 'José Luis Garci'])
# Processing episode cm250328 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm240614 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm240726 with speakers dict_keys(['Noemi Guillermo', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm250613 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm221216 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias', 'Andrés Moret', 'Luis Alberto de Cuenca'])
# Processing episode cm230915 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm220402 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm220716 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm241227 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Luis Enríquez'])
# Processing episode cm221007 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm240920 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'Luis Enríquez'])
# Processing episode cm241213 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm240712 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm240524 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce'])
# Processing episode cm220312 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'Noemi Guillermo'])
# Processing episode cm221105 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci'])
# Processing episode cm241101 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'José Luis Garci'])
# Processing episode cm240607 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm240216 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Luis Enríquez'])
# Processing episode cm250530 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Enríquez'])
# Processing episode cm231222 with speakers dict_keys(['José Luis Garci', 'Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm230120 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Inocencio Arias', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm220409 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm221126 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Carlos Marañón', 'Luis Alberto de Cuenca'])
# Processing episode cm241220 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm220625 with speakers dict_keys(['Inocencio Arias', 'Luis Herrero', 'Luis Alberto de Cuenca'])
# Processing episode cm221119 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm240223 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm250207 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm240426 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm250509 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Luis Enríquez', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm230113 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Noemi Guillermo'])
# Processing episode cm230908 with speakers dict_keys(['José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm230217 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm240119 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm231110 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Luis Enríquez'])
# Processing episode cm250131 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm230630 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'Chema Alonso'])
# Processing episode cm231027 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm230127 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm230707 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Inocencio Arias'])
# Processing episode cm230310 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Guillermo Balmori'])
# Processing episode cm240621 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias', 'Rodrigo Cortés'])
# Processing episode cm230714 with speakers dict_keys(['José Luis Garci', 'Luis Enríquez', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm221029 with speakers dict_keys(['José Luis Garci', 'Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Enríquez', 'Luis Alberto de Cuenca'])
# Processing episode cm230526 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci'])
# Processing episode cm241122 with speakers dict_keys(['Luis Alberto de Cuenca', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Luis Herrero'])
# Processing episode cm230331 with speakers dict_keys(['José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Herrero', 'Luis Alberto de Cuenca'])
# Processing episode cm221203 with speakers dict_keys(['José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Luis Enríquez'])
# Processing episode cm230505 with speakers dict_keys(['Inocencio Arias', 'Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci'])
# Processing episode cm231201 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Miguel Ángel López', 'Noel Ceballos', 'Luis Alberto de Cuenca', 'Emilio del Río', 'Inocencio Arias'])
# Processing episode cm240517 with speakers dict_keys(['Inocencio Arias', 'Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm250307 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'José Luis Garci'])
# Processing episode cm221230 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Enríquez'])
# Processing episode cm230317 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm220507 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm250516 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm230303 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Noemi Guillermo', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm220611 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm221224 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci'])
# Processing episode cm231006 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Paula Ortiz', 'José Luis Garci'])
# Processing episode cm250523 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm220930 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm230609 with speakers dict_keys(['José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Herrero', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm220604 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci'])
# Processing episode cm220326 with speakers dict_keys(['José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Herrero'])
# Processing episode cm250502 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Enríquez', 'Inocencio Arias'])
# Processing episode cm220212 with speakers dict_keys(['Luis Enríquez', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm231013 with speakers dict_keys(['Luis Enríquez', 'Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm220319 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci'])
# Processing episode cm250321 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Inocencio Arias', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm230721 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm250314 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm240126 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm221112 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm220922 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Enríquez', 'Luis Alberto de Cuenca'])
# Processing episode cm230414 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm241011 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Luis Enríquez', 'Eduardo Torres-Dulce'])
# Processing episode cm220909 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'José Luis Garci'])
# Processing episode cm240510 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Enríquez'])
# Processing episode cm250606 with speakers dict_keys(['Luis Enríquez', 'Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm221021 with speakers dict_keys(['Inocencio Arias', 'Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm230922 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm220709 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm240202 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Luis Enríquez'])
# Processing episode cm220205 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm231215 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm240927 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'José Luis Garci'])
# Processing episode cm230428 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm220730 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias', 'José Luis Garci'])
# Processing episode cm221015 with speakers dict_keys(['José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Herrero', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm241206 with speakers dict_keys(['Luis Enríquez', 'Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm220115 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm221210 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce'])
# Processing episode cm231020 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias', 'José Luis Garci'])
# Processing episode cm230616 with speakers dict_keys(['Luis Herrero', 'Luis Enríquez', 'José Luis Garci', 'José Peláez', 'Luis Alberto de Cuenca'])
# Processing episode cm220702 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Emilio del Río', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm230224 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm250411 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm220225 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm240209 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Enríquez'])
# Processing episode cm220917 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm240503 with speakers dict_keys(['Luis Enríquez', 'José Luis Garci', 'Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm250718 with speakers dict_keys(['Luis Enríquez', 'Luis Alberto de Cuenca', 'Luis Herrero', 'Inocencio Arias', 'Eduardo Torres-Dulce'])
# Processing episode cm230512 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm230203 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm241115 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Luis Enríquez', 'Eduardo Torres-Dulce', 'Paula Ortiz'])
# Processing episode cm220723 with speakers dict_keys(['José Luis Garci', 'Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm250110 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Enríquez', 'Luis Alberto de Cuenca'])
# Processing episode cm220521 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'José Luis Garci'])
# Processing episode cm240112 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce', 'Inocencio Arias'])
# Processing episode cm230502 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce'])
# Processing episode cm220618 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm240913 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'José Luis Garci'])
# Processing episode cm231124 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci'])
# Processing episode cm220122 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm240705 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias', 'Carlos Suárez', 'Luis Alberto de Cuenca'])
# Processing episode cm241018 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca', 'Inocencio Arias', 'José Luis Garci'])
# Processing episode cm231208 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias'])
# Processing episode cm220305 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm230421 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'Antonion Chaves', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm250627 with speakers dict_keys(['José Luis Garci', 'Luis Alberto de Cuenca', 'Noemi Guillermo'])
# Processing episode cm240308 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm250425 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Enríquez'])
# Processing episode cm230324 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias'])
# Processing episode cm220528 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm250620 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Luis Enríquez', 'Eduardo Torres-Dulce'])
# Processing episode cm220129 with speakers dict_keys(['José Luis Garci', 'Luis Herrero', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm240322 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm241025 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca', 'Eduardo Torres-Dulce'])
# Processing episode cm240412 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Alberto de Cuenca', 'Inocencio Arias'])
# Processing episode cm220514 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'David Summers', 'Luis Enríquez', 'Luis Alberto de Cuenca'])
# Processing episode cm250214 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias'])
# Processing episode cm240301 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'Luis Enríquez', 'Luis Alberto de Cuenca'])
# Processing episode cm230929 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Luis Alberto de Cuenca'])
# Processing episode cm230728 with speakers dict_keys(['Luis Herrero', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm231103 with speakers dict_keys(['Luis Herrero', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Inocencio Arias', 'Luis Alberto de Cuenca'])
# Processing episode cm240419 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
# Processing episode cm230623 with speakers dict_keys(['Luis Herrero', 'Luis Alberto de Cuenca', 'José Luis Garci', 'Guillermo Balmori', 'Eduardo Torres-Dulce'])
# Processing episode cm240531 with speakers dict_keys(['Luis Alberto de Cuenca', 'Luis Herrero', 'Inocencio Arias', 'Eduardo Torres-Dulce', 'José Luis Garci', 'Guillermo Balmori'])
# Processing episode cm230519 with speakers dict_keys(['Luis Herrero', 'Inocencio Arias', 'José Luis Garci', 'Eduardo Torres-Dulce', 'Luis Alberto de Cuenca'])
